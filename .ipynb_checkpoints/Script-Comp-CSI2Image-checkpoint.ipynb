# %%
# Imports
import torch
import torch.nn as nn
import torch.utils.data as Data
from torchvision import datasets, transforms
from torchinfo import summary
import matplotlib.pyplot as plt
import os
import numpy as np
import random
import time
import CompMethods_CSI2Image as TP
import DataSetting_v5 as DS
# Out:
# F:\Project\Models\Trainer.py:111: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler=GradScaler(),

# %%
date = '2024_Door_EXP/Comp_CSI2Image/'
name = f'{date}CSI2Image_sub_A208'
data_path = [
    '../dataset/Door_EXP/TrainVer/A208',
#             '../dataset/Door_EXP/A308',
#             '../dataset/Door_EXP/B211',
#             '../dataset/Door_EXP/C605_new'
            ]
level = 'subject'

data_organizer = DS.DataOrganizer(name, data_path, level)
data_organizer.load()
# Out:
# Cross validation plan at subject level
# Single-process loading...
# Loaded 0709A00-csi.npy of (125296, 30, 3), elapsed 0.0000 sec
# Skipping 0709A00-csio.npy
# Skipping 0709A00-csitime.npy
# Loaded 0709A00-pd.npy of (125296, 62), elapsed 0.0000 sec
# Loaded 0709A01-csi.npy of (194809, 30, 3), elapsed 0.0000 sec
# Skipping 0709A01-csio.npy
# Skipping 0709A01-csitime.npy
# Loaded 0709A01-pd.npy of (194809, 62), elapsed 0.0010 sec
# Loaded 0709A02-csi.npy of (232687, 30, 3), elapsed 0.0000 sec
# Skipping 0709A02-csio.npy
# Skipping 0709A02-csitime.npy
# Loaded 0709A02-pd.npy of (232687, 62), elapsed 0.0000 sec
# Loaded 0709A03-csi.npy of (167349, 30, 3), elapsed 0.0000 sec
# Skipping 0709A03-csio.npy
# Skipping 0709A03-csitime.npy
# Loaded 0709A03-pd.npy of (167349, 62), elapsed 0.0000 sec
# Loaded 0709A04-csi.npy of (163332, 30, 3), elapsed 0.0000 sec
# Skipping 0709A04-csio.npy
# Skipping 0709A04-csitime.npy
# Loaded 0709A04-pd.npy of (163332, 62), elapsed 0.0000 sec
# Loaded 0709A10-csi.npy of (93119, 30, 3), elapsed 0.0000 sec
# Skipping 0709A10-csio.npy
# Skipping 0709A10-csitime.npy
# Loaded 0709A10-pd.npy of (93119, 62), elapsed 0.0000 sec
# Loaded 0709A101-csi.npy of (56593, 30, 3), elapsed 0.0010 sec
# Skipping 0709A101-csio.npy
# Skipping 0709A101-csitime.npy
# Loaded 0709A101-pd.npy of (56593, 62), elapsed 0.0000 sec
# Loaded 0709A11-csi.npy of (219643, 30, 3), elapsed 0.0000 sec
# Skipping 0709A11-csio.npy
# Skipping 0709A11-csitime.npy
# Loaded 0709A11-pd.npy of (219643, 62), elapsed 0.0000 sec
# Loaded 0709A12-csi.npy of (151822, 30, 3), elapsed 0.0000 sec
# Skipping 0709A12-csio.npy
# Skipping 0709A12-csitime.npy
# Loaded 0709A12-pd.npy of (151822, 62), elapsed 0.0010 sec
# Loaded 0709A13-csi.npy of (163244, 30, 3), elapsed 0.0000 sec
# Skipping 0709A13-csio.npy
# Skipping 0709A13-csitime.npy
# Loaded 0709A13-pd.npy of (163244, 62), elapsed 0.0000 sec
# Loaded 0709A14-csi.npy of (168611, 30, 3), elapsed 0.0000 sec
# Skipping 0709A14-csio.npy
# Skipping 0709A14-csitime.npy
# Loaded 0709A14-pd.npy of (168611, 62), elapsed 0.0000 sec
# Loaded 0709A20-csi.npy of (209993, 30, 3), elapsed 0.0000 sec
# Skipping 0709A20-csio.npy
# Skipping 0709A20-csitime.npy
# Loaded 0709A20-pd.npy of (209993, 62), elapsed 0.0010 sec
# Loaded 0709A21-csi.npy of (179443, 30, 3), elapsed 0.0000 sec
# Skipping 0709A21-csio.npy
# Skipping 0709A21-csitime.npy
# Loaded 0709A21-pd.npy of (179443, 62), elapsed 0.0000 sec
# Loaded 0709A211-csi.npy of (105362, 30, 3), elapsed 0.0000 sec
# Skipping 0709A211-csio.npy
# Skipping 0709A211-csitime.npy
# Loaded 0709A211-pd.npy of (105362, 62), elapsed 0.0000 sec
# Loaded 0709A22-csi.npy of (257318, 30, 3), elapsed 0.0000 sec
# Skipping 0709A22-csio.npy
# Skipping 0709A22-csitime.npy
# Loaded 0709A22-pd.npy of (257318, 62), elapsed 0.0010 sec
# Loaded 0709A23-csi.npy of (111248, 30, 3), elapsed 0.0000 sec
# Skipping 0709A23-csio.npy
# Skipping 0709A23-csitime.npy
# Loaded 0709A23-pd.npy of (111248, 62), elapsed 0.0000 sec
# Loaded 0709A231-csi.npy of (88080, 30, 3), elapsed 0.0000 sec
# Skipping 0709A231-csio.npy
# Skipping 0709A231-csitime.npy
# Loaded 0709A231-pd.npy of (88080, 62), elapsed 0.0000 sec
# Loaded 0709A24-csi.npy of (38347, 30, 3), elapsed 0.0010 sec
# Skipping 0709A24-csio.npy
# Skipping 0709A24-csitime.npy
# Loaded 0709A24-pd.npy of (38347, 62), elapsed 0.0000 sec
# Loaded 0709A241-csi.npy of (128267, 30, 3), elapsed 0.0000 sec
# Skipping 0709A241-csio.npy
# Skipping 0709A241-csitime.npy
# Loaded 0709A241-pd.npy of (128267, 62), elapsed 0.0000 sec
# Loaded 0709A30-csi.npy of (161606, 30, 3), elapsed 0.0010 sec
# Skipping 0709A30-csio.npy
# Skipping 0709A30-csitime.npy
# Loaded 0709A30-pd.npy of (161606, 62), elapsed 0.0000 sec
# Loaded 0709A31-csi.npy of (221354, 30, 3), elapsed 0.0000 sec
# Skipping 0709A31-csio.npy
# Skipping 0709A31-csitime.npy
# Loaded 0709A31-pd.npy of (221354, 62), elapsed 0.0005 sec
# Loaded 0709A32-csi.npy of (165078, 30, 3), elapsed 0.0000 sec
# Skipping 0709A32-csio.npy
# Skipping 0709A32-csitime.npy
# Loaded 0709A32-pd.npy of (165078, 62), elapsed 0.0000 sec
# Loaded 0709A33-csi.npy of (149213, 30, 3), elapsed 0.0000 sec
# Skipping 0709A33-csio.npy
# Skipping 0709A33-csitime.npy
# Loaded 0709A33-pd.npy of (149213, 62), elapsed 0.0000 sec
# Loaded 0709A34-csi.npy of (147801, 30, 3), elapsed 0.0000 sec
# Skipping 0709A34-csio.npy
# Skipping 0709A34-csitime.npy
# Loaded 0709A34-pd.npy of (147801, 62), elapsed 0.0010 sec
# Loaded 0709A40-csi.npy of (169921, 30, 3), elapsed 0.0000 sec
# Skipping 0709A40-csio.npy
# Skipping 0709A40-csitime.npy
# Loaded 0709A40-pd.npy of (169921, 62), elapsed 0.0010 sec
# Loaded 0709A41-csi.npy of (248817, 30, 3), elapsed 0.0000 sec
# Skipping 0709A41-csio.npy
# Skipping 0709A41-csitime.npy
# Loaded 0709A41-pd.npy of (248817, 62), elapsed 0.0010 sec
# Loaded 0709A42-csi.npy of (59402, 30, 3), elapsed 0.0000 sec
# Skipping 0709A42-csio.npy
# Skipping 0709A42-csitime.npy
# Loaded 0709A42-pd.npy of (59402, 62), elapsed 0.0010 sec
# Loaded 0709A421-csi.npy of (155616, 30, 3), elapsed 0.0000 sec
# Skipping 0709A421-csio.npy
# Skipping 0709A421-csitime.npy
# Loaded 0709A421-pd.npy of (155616, 62), elapsed 0.0010 sec
# Loaded 0709A422-csi.npy of (33253, 30, 3), elapsed 0.0000 sec
# Skipping 0709A422-csio.npy
# Skipping 0709A422-csitime.npy
# Loaded 0709A422-pd.npy of (33253, 62), elapsed 0.0000 sec
# Loaded 0709A423-csi.npy of (121848, 30, 3), elapsed 0.0010 sec
# Skipping 0709A423-csio.npy
# Skipping 0709A423-csitime.npy
# Loaded 0709A423-pd.npy of (121848, 62), elapsed 0.0000 sec
# Loaded 0709A4231-csi.npy of (51737, 30, 3), elapsed 0.0000 sec
# Skipping 0709A4231-csio.npy
# Skipping 0709A4231-csitime.npy
# Loaded 0709A4231-pd.npy of (51737, 62), elapsed 0.0000 sec
# Loaded 0709A424-csi.npy of (156881, 30, 3), elapsed 0.0010 sec
# Skipping 0709A424-csio.npy
# Skipping 0709A424-csitime.npy
# Loaded 0709A424-pd.npy of (156881, 62), elapsed 0.0000 sec
# Loaded 0709A50-csi.npy of (133412, 30, 3), elapsed 0.0000 sec
# Skipping 0709A50-csio.npy
# Skipping 0709A50-csitime.npy
# Loaded 0709A50-pd.npy of (133412, 62), elapsed 0.0000 sec
# Loaded 0709A51-csi.npy of (27427, 30, 3), elapsed 0.0000 sec
# Skipping 0709A51-csio.npy
# Skipping 0709A51-csitime.npy
# Loaded 0709A51-pd.npy of (27427, 62), elapsed 0.0010 sec
# Loaded 0709A511-csi.npy of (62914, 30, 3), elapsed 0.0000 sec
# Skipping 0709A511-csio.npy
# Skipping 0709A511-csitime.npy
# Loaded 0709A511-pd.npy of (62914, 62), elapsed 0.0000 sec
# Loaded 0709A512-csi.npy of (82055, 30, 3), elapsed 0.0000 sec
# Skipping 0709A512-csio.npy
# Skipping 0709A512-csitime.npy
# Loaded 0709A512-pd.npy of (82055, 62), elapsed 0.0000 sec
# Loaded 0709A513-csi.npy of (94466, 30, 3), elapsed 0.0000 sec
# Skipping 0709A513-csio.npy
# Skipping 0709A513-csitime.npy
# Loaded 0709A513-pd.npy of (94466, 62), elapsed 0.0000 sec
# Loaded 0709A52-csi.npy of (167964, 30, 3), elapsed 0.0000 sec
# Skipping 0709A52-csio.npy
# Skipping 0709A52-csitime.npy
# Loaded 0709A52-pd.npy of (167964, 62), elapsed 0.0000 sec
# Loaded 0709A53-csi.npy of (56999, 30, 3), elapsed 0.0000 sec
# Skipping 0709A53-csio.npy
# Skipping 0709A53-csitime.npy
# Loaded 0709A53-pd.npy of (56999, 62), elapsed 0.0000 sec
# Loaded 0709A531-csi.npy of (100869, 30, 3), elapsed 0.0000 sec
# Skipping 0709A531-csio.npy
# Skipping 0709A531-csitime.npy
# Loaded 0709A531-pd.npy of (100869, 62), elapsed 0.0000 sec
# Loaded 0709A54-csi.npy of (71925, 30, 3), elapsed 0.0010 sec
# Skipping 0709A54-csio.npy
# Skipping 0709A54-csitime.npy
# Loaded 0709A54-pd.npy of (71925, 62), elapsed 0.0000 sec
# Loaded 0709A541-csi.npy of (71833, 30, 3), elapsed 0.0000 sec
# Skipping 0709A541-csio.npy
# Skipping 0709A541-csitime.npy
# Loaded 0709A541-pd.npy of (71833, 62), elapsed 0.0000 sec
# Skipping 20240709_142959-env-bbx.npy
# Skipping 20240709_142959-env-camtime.npy
# Skipping 20240709_142959-env-cimg.npy
# Skipping 20240709_142959-env-ctr.npy
# Skipping 20240709_142959-env-dpt.npy
# Skipping 20240709_142959-env-rimg.npy
# Skipping 20240709_151047-bbx.npy
# Skipping 20240709_151047-camtime.npy
# Loaded 20240709_151047-cimg.npy of (6329, 1, 128, 128), elapsed 0.0000 sec
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[3], line 12
#       9 level = 'subject'
#      11 data_organizer = DS.DataOrganizer(name, data_path, level)
# ---> 12 data_organizer.load()
#
# File F:\Project\Models\misc.py:13, in timer.<locals>.wrapper(*args, **kwargs)
#      10 @wraps(func)
#      11 def wrapper(*args, **kwargs):
#      12     start = time.time()
# ---> 13     result = func(*args, **kwargs)
#      14     end = time.time()
#      15     print(f"{func.__name__} elapsed: {end - start} sec")
#
# File F:\Project\Models\DataSetting_v5.py:547, in DataOrganizer.load(self, multi)
#     545                     start = time.time()
#     546                     label, data, _ = load_single(file_name_, ext, os.path.join(p, file_name), '', start, etc)
# --> 547                     unpack_results(label, data, fail)
#     549 print(f"\nLoad complete!")
#     550 if fail is not None:
#
# File F:\Project\Models\DataSetting_v5.py:514, in DataOrganizer.load.<locals>.unpack_results(label, data, fail)
#     511         max_value = 65535
#     512     # else:
#     513     #     raise ValueError(f"Only support uint8 or uint16, got {d.dtype}")
# --> 514     d = d.astype(np.float32) / max_value
#     516 self.data[modality][name] = d
#
# UnboundLocalError: local variable 'max_value' referenced before assignment

# %%
data_organizer.load_plan(f'../dataset/Door_EXP/subject_r0.2_A208.pkl')
train_loader, valid_loader, test_loader, current_test = data_organizer.gen_loaders(
    data_organizer=data_organizer,
    subset_ratio=1,
    num_workers=2,
    csi_len=1,
    batch_size=32)

loaders = {
    'train': train_loader,
    'valid': valid_loader,
    'test': test_loader
}

# %%
preprocess = TP.Preprocess(new_size=(64, 64))
gpu = 0
torch.cuda.set_device(gpu)
trainer = TP.CSI2ImageTrainer(name='CSI2Image',
                              loss_optimizer = {'LOSS': [torch.optim.Adam, 1e-4]},
                              lr=2e-4, epochs=300, cuda=gpu,
                              preprocess = preprocess,
                              notion=f'{name}_{current_test}',
                              dataloaders=loaders
                             )

trainer.schedule(early_stop=False)

# %%
da = {}
for p, _, file_lst in os.walk('../dataset/Door_EXP/TrainVer/A208'):
    for file_name in file_lst:
        file_name_, ext = os.path.splitext(file_name)
        if ext == '.npy' and 'rimg' in file_name_:
            da[file_name_] = np.load(os.path.join(p, file_name), mmap_mode='r')
            print(f'loaded {file_name}')
# Out:
# loaded 20240709_142959-env-rimg.npy
# loaded 20240709_153519-rimg.npy
# loaded 20240709_154950-rimg.npy
# loaded 20240709_161802-rimg.npy
# loaded 20240709_163045-rimg.npy
# loaded 20240709_164816-rimg.npy
# loaded 20240709_165643-rimg.npy
# loaded 20240709_185105-rimg.npy
# loaded 20240709_191754-rimg.npy
# loaded 20240709_192745-rimg.npy
# loaded 20240709_193258-rimg.npy
# loaded 20240709_193501-rimg.npy
# loaded 20240709_151047-rimg.npy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_21498/43801877.py in <module>
#       4         file_name_, ext = os.path.splitext(file_name)
#       5         if ext == '.npy' and 'rimg' in file_name_:
# ----> 6             da[file_name_] = np.load(os.path.join(p, file_name), mmap_mode='r')
#       7             print(f'loaded {file_name}')
#
# /opt/conda/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     436             # .npy file
#     437             if mmap_mode:
# --> 438                 return format.open_memmap(file, mode=mmap_mode)
#     439             else:
#     440                 return format.read_array(fid, allow_pickle=allow_pickle,
#
# /opt/conda/lib/python3.7/site-packages/numpy/lib/format.py in open_memmap(filename, mode, dtype, shape, fortran_order, version)
#     865     else:
#     866         # Read the header of the file first.
# --> 867         with open(os_fspath(filename), 'rb') as fp:
#     868             version = read_magic(fp)
#     869             _check_version(version)
#
# KeyboardInterrupt:
